# %% [markdown]
# ### Numerical Experiments
#
# First experiment: degree of the sparse grid is tested

# %%
import openml

from openml import tasks

import HPO

import pysgpp

import sys

import math
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import sklearn.metrics

from sklearn.model_selection import cross_val_score

import numpy as np
import keras
from keras import backend as K

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
from scikeras.wrappers import KerasRegressor, KerasClassifier


BUDGET = 30
VERBOSE = 1
CV = [(slice(None), slice(None))]
SCORING = 'neg_mean_squared_error'
TESTING = False

DATASETS = []
# Out:
# 2023-04-19 16:50:42.153412: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-19 16:50:43.464922: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Hyperparameter space definition

# %%
DEGREES = 5

hyperparameterspace = {
    'epochs': ["interval-int", 1, 30],
    'batch_size': ["interval-int", 10, 200],
    'optimizer__learning_rate': ["interval-log", 0.0000001, 0.01],
    'model__neurons_per_layer': ["interval-int", 1, 100],
    'model__number_of_layers': ["interval-int", 1, 10],
}

hyperparameterspace_special = {}
for key in hyperparameterspace.keys():
    liste = []
    for i in range(1, len(hyperparameterspace[key])):
        liste.append(hyperparameterspace[key][i])
    hyperparameterspace_special[key] = liste

# %%
ids = [233214, 233211, 359935, 359952, 359940]#, 359931, 317614, 359949, 359934, 359946, 359938, 359932, 359943]

def relu_advanced(x):
    return K.relu(x)

ACTIVATION_FUNCTION = relu_advanced

RESULTS_datasets = [[] for _ in range(len(ids))]

valid_datasets = 0
for i in range(len(ids)):

    dataset = HPO.Dataset(task_id=ids[i])

    class ExampleFunction(pysgpp.ScalarFunction):

        def __init__(self):
            super(ExampleFunction, self).__init__(len(hyperparameterspace.keys()))


        def eval(self, x):
            #index = int(x[0]*(len(hyperparameterspace_special["loss"])-1))
            loss = 'mean_squared_error'#hyperparameterspace_special["loss"][index]
            
            epochs = int(HPO.from_standard(hyperparameterspace_special["epochs"][0], hyperparameterspace_special["epochs"][1], x[0]))

            batch_size = int(HPO.from_standard(hyperparameterspace_special["batch_size"][0], hyperparameterspace_special["batch_size"][1], x[1]))

            model_learning_rate = HPO.from_standard_log(hyperparameterspace_special["optimizer__learning_rate"][0], hyperparameterspace_special["optimizer__learning_rate"][1], x[2])
            
            neurons_per_layer = int(HPO.from_standard(hyperparameterspace_special["model__neurons_per_layer"][0], hyperparameterspace_special["model__neurons_per_layer"][1], x[3]))

            number_of_layers = int(HPO.from_standard(hyperparameterspace_special["model__number_of_layers"][0], hyperparameterspace_special["model__number_of_layers"][1], x[4]))

            # Function to create model, required for KerasClassifier
            def create_model():
                # create model
                model = Sequential()
                model.add(Dense(neurons_per_layer, input_shape=(len(dataset.get_X()[0]),), activation=ACTIVATION_FUNCTION))
                for _ in range(number_of_layers):
                    model.add(Dense(neurons_per_layer, activation=ACTIVATION_FUNCTION))
                model.add(Dense(1, activation=None))
                # Compile model
                
                optimizer = keras.optimizers.Adam(learning_rate=model_learning_rate)

                model.compile(loss=loss, optimizer=optimizer,)
                return model

            model = KerasRegressor(model=create_model, verbose=0)

            model.fit(dataset.get_X_train(), dataset.get_Y_train(), epochs=epochs, batch_size=batch_size)

            if TESTING:
                Y_predicted = model.predict(dataset.get_X_test())
                result = sklearn.metrics.mean_squared_error(dataset.get_Y_test().tolist(), Y_predicted)
                K.clear_session()
                return result
            else:
                Y_predicted = model.predict(dataset.get_X_validation())
                result = sklearn.metrics.mean_squared_error(dataset.get_Y_validation().tolist(), Y_predicted)
                K.clear_session()
                return result


    results_temp = []
    results_opt_temp = []

    for j in range(DEGREES):
        print("Current degree:", j+1)

        sparse_params=[j+1, 0.95, "gradient_descent"]

        f = ExampleFunction()

        optimization = HPO.SparseGridSearchOptimization(dataset, f, hyperparameterspace, budget=BUDGET, verbosity=VERBOSE, degree=sparse_params[0], adaptivity=sparse_params[1], optimizer=sparse_params[2])

        result = optimization.fit()

        TESTING = True
        results_temp.append(f.eval(result[0]))
        results_temp.append(f.eval(result[1]))
        TESTING = False

    for m in range(len(results_temp)):
        RESULTS_datasets[i].append(results_temp[m])
# Out:
# Current degree: 1
# Adaptive grid generation (Ritter-Novak)...
# 2023-04-19 16:50:56.108501: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Done in 367167ms.
# Solving linear system (automatic method)...
# Done in 4ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 57.5
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 25.75
# model__number_of_layers: 5.5
# Resulting loss:
# 0.8195523608202588
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.999996284756406
# batch_size: 199.99987911538807
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 1.0000529287542201
# model__number_of_layers: 9.999992690863989
# Resulting loss (Optimal value from optimization):
# -1.4327662715487606
# Resulting loss (Optimal point evaluated):
# 0.9285742874751077
# Current degree: 2
# Adaptive grid generation (Ritter-Novak)...
# Done in 355300ms.
# Solving linear system (automatic method)...
# Done in 9ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 25.75
# model__number_of_layers: 5.5
# Resulting loss:
# 0.8152897851295663
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 25.75
# model__number_of_layers: 5.5
# Resulting loss (Optimal value from optimization):
# 0.8152897851295663
# Resulting loss (Optimal point evaluated):
# 0.8394603880576288
# Current degree: 3
# Adaptive grid generation (Ritter-Novak)...
# Done in 353136ms.
# Solving linear system (automatic method)...
# Done in 5ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 57.5
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 25.75
# model__number_of_layers: 5.5
# Resulting loss:
# 0.8141577991158573
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.999972283709095
# batch_size: 10.000031632285223
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 1.0000297058102858
# model__number_of_layers: 3.763202758094443
# Resulting loss (Optimal value from optimization):
# -1.06586134439787
# Resulting loss (Optimal point evaluated):
# 0.9285730224876668
# Current degree: 4
# Adaptive grid generation (Ritter-Novak)...
# Done in 344065ms.
# Solving linear system (automatic method)...
# Done in 5ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.7998285730445541
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 1.0000142089524222
# batch_size: 199.99988797480896
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 1.0000681009927705
# model__number_of_layers: 9.99999797313218
# Resulting loss (Optimal value from optimization):
# -3.2882567665231885
# Resulting loss (Optimal point evaluated):
# 0.9281367434266635
# Current degree: 5
# Adaptive grid generation (Ritter-Novak)...
# Done in 351810ms.
# Solving linear system (automatic method)...
# Done in 5ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 50.5
# model__number_of_layers: 3.25
# Resulting loss:
# 0.8091262398462805
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 1.0000119638519782
# batch_size: 199.9999099820557
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 64.46552390540039
# model__number_of_layers: 9.999995506204097
# Resulting loss (Optimal value from optimization):
# -1.250628134012259
# Resulting loss (Optimal point evaluated):
# 0.855365328904808
# Current degree: 1
# Adaptive grid generation (Ritter-Novak)...
# Done in 1142322ms.
# Solving linear system (automatic method)...
# Done in 8ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.01968845020015633
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.999976821111176
# batch_size: 10.000108931784773
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 1.000016996732564
# model__number_of_layers: 9.999996891834481
# Resulting loss (Optimal value from optimization):
# -0.11414117768560586
# Resulting loss (Optimal point evaluated):
# 1.0235987320720337
# Current degree: 2
# Adaptive grid generation (Ritter-Novak)...
# Done in 1134686ms.
# Solving linear system (automatic method)...
# Done in 5ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 75.25
# model__number_of_layers: 5.5
# Resulting loss:
# 0.019327885670422363
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 75.25
# model__number_of_layers: 5.5
# Resulting loss (Optimal value from optimization):
# 0.019327885670422363
# Resulting loss (Optimal point evaluated):
# 0.019805630442068786
# Current degree: 3
# Adaptive grid generation (Ritter-Novak)...
# Done in 1123433ms.
# Solving linear system (automatic method)...
# Done in 6ms.
#
# Optimal hyperparameters so far:
# epochs: 22.75
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.01955198770228466
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.999978804293708
# batch_size: 10.000063193073494
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 99.99994552023514
# model__number_of_layers: 5.726579031406969
# Resulting loss (Optimal value from optimization):
# -0.21532408470011694
# Resulting loss (Optimal point evaluated):
# 0.02255219716671068
# Current degree: 4
# Adaptive grid generation (Ritter-Novak)...
# Done in 1175538ms.
# Solving linear system (automatic method)...
# Done in 8ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.019935582933398917
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.999993910815355
# batch_size: 10.000140350157492
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 99.99992034474657
# model__number_of_layers: 6.408670338442126
# Resulting loss (Optimal value from optimization):
# -0.30141159722255473
# Resulting loss (Optimal point evaluated):
# 0.04859687450186342
# Current degree: 5
# Adaptive grid generation (Ritter-Novak)...
# Done in 1166536ms.
# Solving linear system (automatic method)...
# Done in 6ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.01986275641083198
# Optimizing (gradient descent)...
# Done in 3ms.
#
# Optimal hyperparameters after optimization:
# epochs: 13.661740015785208
# batch_size: 106.45344496167287
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 28.670139581441745
# model__number_of_layers: 5.235797206907325
# Resulting loss (Optimal value from optimization):
# 0.0037772504580471035
# Resulting loss (Optimal point evaluated):
# 0.025498006800745862
# Current degree: 1
# Adaptive grid generation (Ritter-Novak)...
# Done in 229810ms.
# Solving linear system (automatic method)...
# Done in 2ms.
#
# Optimal hyperparameters so far:
# epochs: 22.75
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.6055482127773125
# Optimizing (gradient descent)...
# Done in 2ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.999983268440797
# batch_size: 199.99986698776792
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 99.99996982200274
# model__number_of_layers: 1.0000072388846835
# Resulting loss (Optimal value from optimization):
# -0.05117736868971973
# Resulting loss (Optimal point evaluated):
# 0.6221800246209688
# Current degree: 2
# Adaptive grid generation (Ritter-Novak)...
# Done in 231299ms.
# Solving linear system (automatic method)...
# Done in 5ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 152.5
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.5922882825149576
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 1.0000289058097056
# batch_size: 104.9997405036309
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 62.87613808656915
# model__number_of_layers: 3.249999988753283
# Resulting loss (Optimal value from optimization):
# 0.23293274860953714
# Resulting loss (Optimal point evaluated):
# 0.6963330343759794
# Current degree: 3
# Adaptive grid generation (Ritter-Novak)...
# Done in 224842ms.
# Solving linear system (automatic method)...
# Done in 5ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 50.5
# model__number_of_layers: 3.25
# Resulting loss:
# 0.5900117450885622
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.99997611003399
# batch_size: 10.000185381493905
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 1.0000350675436553
# model__number_of_layers: 1.0000053888277711
# Resulting loss (Optimal value from optimization):
# -2.273186375092107
# Resulting loss (Optimal point evaluated):
# 0.9470219840425956
# Current degree: 4
# Adaptive grid generation (Ritter-Novak)...
# Done in 222034ms.
# Solving linear system (automatic method)...
# Done in 5ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.5995119253686991
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 1.0000172314746547
# batch_size: 199.99998464856995
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 99.99997130899004
# model__number_of_layers: 9.999999526597056
# Resulting loss (Optimal value from optimization):
# -0.799068047583458
# Resulting loss (Optimal point evaluated):
# 0.8252025487478236
# Current degree: 5
# Adaptive grid generation (Ritter-Novak)...
# Done in 218110ms.
# Solving linear system (automatic method)...
# Done in 4ms.
#
# Optimal hyperparameters so far:
# epochs: 22.75
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.6009640717927522
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.99998128600183
# batch_size: 10.00009630923713
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 1.0000761979242367
# model__number_of_layers: 9.999999284264717
# Resulting loss (Optimal value from optimization):
# -1.6075888734424346
# Resulting loss (Optimal point evaluated):
# 0.9511317924310237
# Current degree: 1
# Adaptive grid generation (Ritter-Novak)...
# Done in 539689ms.
# Solving linear system (automatic method)...
# Done in 2ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 75.25
# model__number_of_layers: 5.5
# Resulting loss:
# 0.41998878034733444
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 75.25
# model__number_of_layers: 5.5
# Resulting loss (Optimal value from optimization):
# 0.41998878034733444
# Resulting loss (Optimal point evaluated):
# 0.46246768073813915
# Current degree: 2
# Adaptive grid generation (Ritter-Novak)...
# Done in 537055ms.
# Solving linear system (automatic method)...
# Done in 8ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.40239317703345845
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 11.874999548453909
# batch_size: 105.00000168036367
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 32.02371614943152
# model__number_of_layers: 6.561176713766286
# Resulting loss (Optimal value from optimization):
# 0.20302430899527948
# Resulting loss (Optimal point evaluated):
# 0.4792951546288102
# Current degree: 3
# Adaptive grid generation (Ritter-Novak)...
# Done in 540156ms.
# Solving linear system (automatic method)...
# Done in 3ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.41715159776694494
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 1.000010854697216
# batch_size: 199.99990116947518
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 1.0000882968235016
# model__number_of_layers: 1.0000007069977783
# Resulting loss (Optimal value from optimization):
# -2.707840899450957
# Resulting loss (Optimal point evaluated):
# 0.7576502615007495
# Current degree: 4
# Adaptive grid generation (Ritter-Novak)...
# Done in 536168ms.
# Solving linear system (automatic method)...
# Done in 7ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.4067734007315224
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 1.0000139783875854
# batch_size: 199.99992186847382
# optimizer__learning_rate: 0.002371373705661655
# model__neurons_per_layer: 1.000072544233439
# model__number_of_layers: 9.99999186043898
# Resulting loss (Optimal value from optimization):
# -2.3020531579754633
# Resulting loss (Optimal point evaluated):
# 1.0028199491271828
# Current degree: 5
# Adaptive grid generation (Ritter-Novak)...
# Done in 547041ms.
# Solving linear system (automatic method)...
# Done in 3ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 57.5
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.4093592151522827
# Optimizing (gradient descent)...
# Done in 1ms.
#
# Optimal hyperparameters after optimization:
# epochs: 17.12964881301083
# batch_size: 10.000162085812732
# optimizer__learning_rate: 0.0005623413251903491
# model__neurons_per_layer: 1.000025154096424
# model__number_of_layers: 4.313619245461767
# Resulting loss (Optimal value from optimization):
# -0.582120040179534
# Resulting loss (Optimal point evaluated):
# 1.0024615012989122
# Current degree: 1
# Adaptive grid generation (Ritter-Novak)...
# Done in 283170ms.
# Solving linear system (automatic method)...
# Done in 7ms.
#
# Optimal hyperparameters so far:
# epochs: 26.375
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss:
# 0.8494595656033861
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 26.375
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 50.5
# model__number_of_layers: 5.5
# Resulting loss (Optimal value from optimization):
# 0.8494595656033861
# Resulting loss (Optimal point evaluated):
# 0.8802252579564622
# Current degree: 2
# Adaptive grid generation (Ritter-Novak)...
# Done in 275537ms.
# Solving linear system (automatic method)...
# Done in 5ms.
#
# Optimal hyperparameters so far:
# epochs: 22.75
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 50.5
# model__number_of_layers: 7.75
# Resulting loss:
# 0.8435027431633498
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 22.75
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 50.5
# model__number_of_layers: 7.75
# Resulting loss (Optimal value from optimization):
# 0.8435027431633498
# Resulting loss (Optimal point evaluated):
# 0.8691162316812959
# Current degree: 3
# Adaptive grid generation (Ritter-Novak)...
# Done in 249808ms.
# Solving linear system (automatic method)...
# Done in 3ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 75.25
# model__number_of_layers: 7.75
# Resulting loss:
# 0.8597508522007049
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 29.999979854069483
# batch_size: 199.99981290043993
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 99.99999049334826
# model__number_of_layers: 3.8972629844615105
# Resulting loss (Optimal value from optimization):
# -0.1987412657837152
# Resulting loss (Optimal point evaluated):
# 0.9540290140070713
# Current degree: 4
# Adaptive grid generation (Ritter-Novak)...
# Done in 184944ms.
# Solving linear system (automatic method)...
# Done in 2ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 105.0
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 75.25
# model__number_of_layers: 5.5
# Resulting loss:
# 0.849491783085603
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 16.21203817949084
# batch_size: 93.89667469662545
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 75.77507266374968
# model__number_of_layers: 6.217145896809012
# Resulting loss (Optimal value from optimization):
# 0.8379688909176408
# Resulting loss (Optimal point evaluated):
# 0.8599319885566132
# Current degree: 5
# Adaptive grid generation (Ritter-Novak)...
# Done in 187595ms.
# Solving linear system (automatic method)...
# Done in 3ms.
#
# Optimal hyperparameters so far:
# epochs: 15.5
# batch_size: 57.5
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 75.25
# model__number_of_layers: 5.5
# Resulting loss:
# 0.8521012514095392
# Optimizing (gradient descent)...
# Done in 0ms.
#
# Optimal hyperparameters after optimization:
# epochs: 1.0000099460470686
# batch_size: 10.000119736183047
# optimizer__learning_rate: 3.1622776601683795e-05
# model__neurons_per_layer: 1.0000266897568268
# model__number_of_layers: 9.999997998480476
# Resulting loss (Optimal value from optimization):
# -1.158226889581921
# Resulting loss (Optimal point evaluated):
# 0.8957040529624902

# %% [markdown]
# ### Plotting

# %%
print(RESULTS_datasets)

for i in range(len(ids)):
    print("Dataset with id", ids[i])

    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])

    opts = []
    k = 0
    for degree in range(DEGREES):
        opts.append(str(degree+1))
        opts.append(str(degree+1)+" (opt)")
        k += 1

    ax.bar(opts, RESULTS_datasets[i])
    # plt.ylim(0.9*min(RESULTS_datasets[i]), None)
    plt.show()
# Out:
# [[0.9734121699214973, 1.1183019972199817, 1.1146319078028977, 1.0171487553382934, 0.9470609084024543, 1.1183049434671715, 0.9512754073418728, 1.1223943119723503, 1.0029967593059255, 0.9581635220196026], [0.047464429356982515, 0.9992078419423798, 0.04536931782867786, 0.10703619805415154, 0.04138910041771715, 0.025466498366858104, 0.12886145338455746, 0.027340553134794023, 0.11444435911217907, 0.04888903582811867], [0.6273761187743876, 0.6434160663142455, 0.6176879533200328, 0.6999783144694138, 0.6152321176988778, 0.7099180236713178, 0.6195746942203979, 0.742595580581147, 0.646893568348356, 1.0014004260121103], [0.47804752408252316, 0.4303580809203044, 0.46289110359897706, 0.4646183622926405, 0.420201737857677, 0.8651447977932915, 0.4190275237565558, 1.0643391201888626, 0.4390956004673389, 1.0643590174662776], [0.9006069589804395, 0.9020863772871979, 0.8994242443709097, 0.9101238931721273, 0.8824377319881267, 1.0460986832405559, 0.8967944150398354, 0.9110248278543561, 0.8985935495915076, 0.9285739207788567]]
# Dataset with id 233214
# Dataset with id 233211
# Dataset with id 359935
# Dataset with id 359952
# Dataset with id 359940
