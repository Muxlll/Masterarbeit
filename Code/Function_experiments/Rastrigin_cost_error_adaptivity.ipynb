# %% [markdown]
# ### Baseline experiment
#
# Experiment to compare the 4 Optimization algorithms before trying to improve sparse search

# %%
import HPO
import pysgpp
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn.metrics
from sklearn.model_selection import KFold
import numpy as np
import keras
from keras import backend as K
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.compose import ColumnTransformer
from sklearn.compose import TransformedTargetRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from numpy.random import seed
import random
import time
import os
import math
from matplotlib import cm
import matplotlib 

# matplotlib.use("pgf")
# matplotlib.rcParams.update({
#     "pgf.texsystem": "pdflatex",
#     'font.family': 'serif',
#     'text.usetex': True,
#     'pgf.rcfonts': False,
# })

random.seed(1)
seed(2)
tf.random.set_seed(3)

def reset_seeds():
    np.random.seed(1)
    random.seed(2)
    tf.random.set_seed(3)

VERBOSE = 0

SPARSE_RESULT = []
SPARSE_RESULT_OPTIMIZED = []

SPARSE_COST = []
SPARSE_COST_OPTIMIZED = []

# %% [markdown]
# ### Hyperparameter space definition

# %%
hyperparameterspace = {
    'x0': ["interval", -2, 8],
    'x1': ["interval", -2, 8],
    #'learning_rate': ["interval-log", 0.000000001, 0.1],
    #'number_layers': ["interval-int", 1, 20],
    #'neurons_per_layer': ["interval-int", 1, 50]
}

hyperparameterspace_special = {}
for key in hyperparameterspace.keys():
    liste = []
    for i in range(1, len(hyperparameterspace[key])):
        liste.append(hyperparameterspace[key][i])
    hyperparameterspace_special[key] = liste

# %% [markdown]
# ### Experiment parameters

# %%
DIRECTORY = "Current_tests/"+time.strftime("%H_%M_%S", time.localtime())

ADAPTIVITIES = [0.0, 0.25, 0.5, 0.75, 1.0]

RESULTS_0 = "{"
RESULTS_0_25 = "{"
RESULTS_0_5 = "{"
RESULTS_0_75 = "{"
RESULTS_1 = "{"

BUDGETS = [1 + i * 52 for i in range(19)]

# %% [markdown]
# ### Optimization

# %%
# os.mkdir(DIRECTORY)

# f = open(DIRECTORY+"/configurations.txt", "a")
# f.write("Dimension of hyperparameter space: " +
#         str(len(hyperparameterspace)) + "\n")
# for key in hyperparameterspace.keys():
#     f.write("\n" + key + ": " + str(hyperparameterspace[key]))
# f.write("\n\nSparse grid degree: " + str(SPARSE_PARAMS[0]))
# f.write("\nSparse grid adaptivity param: " + str(SPARSE_PARAMS[1]))
# f.write("\nSparse grid optimization alg: " + str(SPARSE_PARAMS[2]))
# f.write("\nBUDGETS: " + str(BUDGETS))
# f.close()


################## MODEL AND FUNCTION DEFINITION ####################

def evaluate_model(epochs, batch_size, learning_rate, number_of_layers, neurons_per_layer, deterministic=True):

    # ################# RASTRIGIN #################
    sum = 0
    sum += epochs ** 2 - 10 * math.cos(2 * math.pi * epochs)
    sum += batch_size ** 2 - 10 * math.cos(2 * math.pi * batch_size)
    # sum += learning_rate ** 2 - 10 * math.cos(2 * math.pi * learning_rate)
    # sum += number_of_layers ** 2 - 10 * math.cos(2 * math.pi * number_of_layers)
    # sum += neurons_per_layer ** 2 - 10 * math.cos(2 * math.pi * neurons_per_layer)
    return len(hyperparameterspace) * 10 + sum

    ################# ROSENBROCK #################
    # sum = 0
    # sum += (1-epochs)**2 + 100 * (batch_size - epochs**2) ** 2
    # return sum

    ################# EGGHOLDER #################
    # return -epochs * math.sin(math.sqrt(abs(epochs - (batch_size + 47)))) - (batch_size + 47) * math.sin(math.sqrt(abs((batch_size + 47 + 0.5 * epochs))))

    # return epochs + batch_size + learning_rate + number_of_layers + neurons_per_layer


class ExampleFunction(pysgpp.ScalarFunction):

    def __init__(self):
        super(ExampleFunction, self).__init__(
            len(hyperparameterspace.keys()))

    def eval(self, x):
        # index = int(x[0]*(len(hyperparameterspace_special["loss"])-1))
        # hyperparameterspace_special["loss"][index]

        epochs = (HPO.from_standard(
            hyperparameterspace_special["x0"][0], hyperparameterspace_special["x0"][1], x[0]))

        batch_size = (HPO.from_standard(
            hyperparameterspace_special["x1"][0], hyperparameterspace_special["x1"][1], x[1]))

        # HPO.from_standard_log(hyperparameterspace_special["learning_rate"][
        model_learning_rate = 0
        #                  0], hyperparameterspace_special["learning_rate"][1], x[2])

        number_of_layers = 0  # int(HPO.from_standard(
        # hyperparameterspace_special["number_layers"][0], hyperparameterspace_special["number_layers"][1], x[3]))

        neurons_per_layer = 0  # int(HPO.from_standard(
        # hyperparameterspace_special["neurons_per_layer"][0], hyperparameterspace_special["neurons_per_layer"][1], x[4]))

        return evaluate_model(epochs, batch_size, model_learning_rate, number_of_layers, neurons_per_layer)


# resolution = 200

# x = np.linspace(-2, 8, resolution)
# y = np.linspace(-2, 8, resolution)

# X, Y = np.meshgrid(x, y)

# Z = np.zeros((resolution, resolution))

# for i in range(resolution):
#     for j in range(resolution):
#         Z[i][j] = evaluate_model(X[i][j], Y[i][j], 0, 0, 0)


# fig = plt.figure()
# ax = plt.axes(projection='3d')
# surface = ax.plot_surface(X, Y, Z, cmap='plasma')
# ax.set_xlabel('x0')
# ax.set_ylabel('x1')
# ax.set_zlabel('y')
# fig.colorbar(surface, shrink=0.8, aspect=15)
# plt.savefig("./Testfunctions/Rastrigin_normal.pgf",bbox_inches='tight' )
# plt.show()


# fig = plt.figure()
# ax = plt.axes(projection='3d')
# surface = ax.plot_surface(X, Y, Z, cmap='plasma')
# ax.set_xlabel('x0')
# ax.set_ylabel('x1')
# ax.set_zlabel('y')
# ax.set_zticks([])
# ax.view_init(90, 270)
# fig.colorbar(surface, shrink=0.8, aspect=15)
# plt.savefig("./Testfunctions/Rastrigin_above.pgf",bbox_inches='tight' )
# plt.show()

#### For each dataset: run models with different budget #####
for BUDGET in BUDGETS:

    print("\n################################################## Current Budget:",
            BUDGET, "##################################################")

    ########################### SPARSE OPT ############################

    print("\nPerforming sparse search")

    f = ExampleFunction()
    dataset = HPO.Dataset([], [])

    optimization = HPO.SparseGridSearchOptimization(
        dataset, f, hyperparameterspace, budget=BUDGET, verbosity=VERBOSE, degree=2, adaptivity=ADAPTIVITIES[0], optimizer="gradient_descent")

    result = optimization.fit()

    RESULTS_0 += "(" + str(result[1]) + "," + str(result[0][1]) + ")"
    print(result[1])


    ########################### SPARSE OPT ############################

    f = ExampleFunction()
    dataset = HPO.Dataset([], [])

    optimization = HPO.SparseGridSearchOptimization(
        dataset, f, hyperparameterspace, budget=BUDGET, verbosity=VERBOSE, degree=2, adaptivity=ADAPTIVITIES[1], optimizer="gradient_descent")

    result = optimization.fit()

    RESULTS_0_25 += "(" + str(result[1]) + "," + str(result[0][1]) + ")"

    ########################### SPARSE OPT ############################

    f = ExampleFunction()
    dataset = HPO.Dataset([], [])

    optimization = HPO.SparseGridSearchOptimization(
        dataset, f, hyperparameterspace, budget=BUDGET, verbosity=VERBOSE, degree=2, adaptivity=ADAPTIVITIES[2], optimizer="gradient_descent")

    result = optimization.fit()

    RESULTS_0_5 += "(" + str(result[1]) + "," + str(result[0][1]) + ")"

    ########################### SPARSE OPT ############################

    f = ExampleFunction()
    dataset = HPO.Dataset([], [])

    optimization = HPO.SparseGridSearchOptimization(
        dataset, f, hyperparameterspace, budget=BUDGET, verbosity=VERBOSE, degree=2, adaptivity=ADAPTIVITIES[3], optimizer="gradient_descent")

    result = optimization.fit()

    RESULTS_0_75 += "(" + str(result[1]) + "," + str(result[0][1]) + ")"

    ########################### SPARSE OPT ############################

    f = ExampleFunction()
    dataset = HPO.Dataset([], [])

    optimization = HPO.SparseGridSearchOptimization(
        dataset, f, hyperparameterspace, budget=BUDGET, verbosity=VERBOSE, degree=2, adaptivity=ADAPTIVITIES[4], optimizer="gradient_descent")

    result = optimization.fit()
    print(result)

    RESULTS_1 += "(" + str(result[1]) + "," + str(result[0][1]) + ")"


RESULTS_0 += "}"
RESULTS_0_25 += "}"
RESULTS_0_5 += "}"
RESULTS_0_75 += "}"
RESULTS_1 += "}"

print(RESULTS_0)
print(RESULTS_0_25)
print(RESULTS_0_5)
print(RESULTS_0_75)
print(RESULTS_1)
# Out:
# ################################################## Current Budget: 1 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 0ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 0ms.
# 1
# Adaptive grid generation (Ritter-Novak)...
# Done in 0ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 0ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 0ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 0ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 0ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 0ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 0ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 0ms.
# ([[0.5, 0.5], 18.0, [0.5, 0.5], 18.0], 1)
#
# ################################################## Current Budget: 53 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 1ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 1ms.
# 53
# Adaptive grid generation (Ritter-Novak)...
# Done in 1ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 1ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 1ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 1ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 1ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 0ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 1ms.
# Solving linear system (automatic method)...
# Done in 0ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# ([[0.1875, 0.5], 11.944557188134524, [0.18622630313161043, 0.00040206099347290473], 7.522944465276709], 53)
#
# ################################################## Current Budget: 105 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 3ms.
# Solving linear system (automatic method)...
# Done in 1ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 2ms.
# 105
# Adaptive grid generation (Ritter-Novak)...
# Done in 3ms.
# Solving linear system (automatic method)...
# Done in 1ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 2ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 3ms.
# Solving linear system (automatic method)...
# Done in 1ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 2ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 4ms.
# Solving linear system (automatic method)...
# Done in 1ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 2ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 2ms.
# Solving linear system (automatic method)...
# Done in 1ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 2ms.
# ([[0.1875, 0.5], 11.944557188134521, [0.18749770002405974, 0.18728475804834316], 5.986957994233288], 105)
#
# ################################################## Current Budget: 157 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 4ms.
# Solving linear system (automatic method)...
# Done in 6ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 3ms.
# 157
# Adaptive grid generation (Ritter-Novak)...
# Done in 4ms.
# Solving linear system (automatic method)...
# Done in 5ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 3ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 7ms.
# Solving linear system (automatic method)...
# Done in 4ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 3ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 4ms.
# Solving linear system (automatic method)...
# Done in 4ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 3ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 3ms.
# Solving linear system (automatic method)...
# Done in 4ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 3ms.
# ([[0.296875, 0.5], 10.130623758467696, [0.2971561413712649, 0.18808282908105808], 3.792137342163077], 157)
#
# ################################################## Current Budget: 209 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 8ms.
# Solving linear system (automatic method)...
# Done in 59ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# 209
# Adaptive grid generation (Ritter-Novak)...
# Done in 5ms.
# Solving linear system (automatic method)...
# Done in 58ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 2ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 4ms.
# Solving linear system (automatic method)...
# Done in 49ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 2ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 3ms.
# Solving linear system (automatic method)...
# Done in 43ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 5ms.
# Solving linear system (automatic method)...
# Done in 25ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 3ms.
# ([[0.296875, 0.5], 10.130623758467692, [0.29682115973694734, 0.297749110095166], 2.1915677537490232], 209)
#
# ################################################## Current Budget: 261 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 5ms.
# Solving linear system (automatic method)...
# Done in 65ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# 261
# Adaptive grid generation (Ritter-Novak)...
# Done in 5ms.
# Solving linear system (automatic method)...
# Done in 73ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 5ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 5ms.
# Solving linear system (automatic method)...
# Done in 83ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 5ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 15ms.
# Solving linear system (automatic method)...
# Done in 73ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 3ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 4ms.
# Solving linear system (automatic method)...
# Done in 40ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# ([[0.203125, 0.5], 9.193123758467797, [0.20298792853381614, 0.20330740307424638], 0.3928453285580886], 261)
#
# ################################################## Current Budget: 313 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 8ms.
# Solving linear system (automatic method)...
# Done in 106ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 3ms.
# 313
# Adaptive grid generation (Ritter-Novak)...
# Done in 7ms.
# Solving linear system (automatic method)...
# Done in 108ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 9ms.
# Solving linear system (automatic method)...
# Done in 119ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 8ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 13ms.
# Solving linear system (automatic method)...
# Done in 129ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 8ms.
# Solving linear system (automatic method)...
# Done in 82ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 8ms.
# ([[0.203125, 0.5], 9.193123758467703, [0.20284649568861285, 0.19976184657176382], 0.16144725792020864], 313)
#
# ################################################## Current Budget: 365 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 11ms.
# Solving linear system (automatic method)...
# Done in 186ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# 365
# Adaptive grid generation (Ritter-Novak)...
# Done in 12ms.
# Solving linear system (automatic method)...
# Done in 187ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 5ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 13ms.
# Solving linear system (automatic method)...
# Done in 179ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 9ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 15ms.
# Solving linear system (automatic method)...
# Done in 187ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 4ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 10ms.
# Solving linear system (automatic method)...
# Done in 82ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 7ms.
# ([[0.203125, 0.5], 9.193123758467696, [0.20355749806557616, 0.2031732625709362], 0.4491577242463407], 365)
#
# ################################################## Current Budget: 417 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 10ms.
# Solving linear system (automatic method)...
# Done in 226ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 8ms.
# 417
# Adaptive grid generation (Ritter-Novak)...
# Done in 18ms.
# Solving linear system (automatic method)...
# Done in 319ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 8ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 18ms.
# Solving linear system (automatic method)...
# Done in 217ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 6ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 18ms.
# Solving linear system (automatic method)...
# Done in 234ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 7ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 9ms.
# Solving linear system (automatic method)...
# Done in 105ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 8ms.
# ([[0.203125, 0.5], 9.1931237584677, [0.20179285522220358, 0.20345471865035109], 0.29956167256458244], 417)
#
# ################################################## Current Budget: 469 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 22ms.
# Solving linear system (automatic method)...
# Done in 243ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 8ms.
# 469
# Adaptive grid generation (Ritter-Novak)...
# Done in 13ms.
# Solving linear system (automatic method)...
# Done in 270ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 5ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 13ms.
# Solving linear system (automatic method)...
# Done in 256ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 5ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 13ms.
# Solving linear system (automatic method)...
# Done in 266ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 7ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 11ms.
# Solving linear system (automatic method)...
# Done in 179ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 13ms.
# ([[0.203125, 0.5], 9.1931237584677, [0.20240055979016702, 0.20143002349321318], 0.15465504725302281], 469)
#
# ################################################## Current Budget: 521 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 43ms.
# Solving linear system (automatic method)...
# Done in 414ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 9ms.
# 521
# Adaptive grid generation (Ritter-Novak)...
# Done in 18ms.
# Solving linear system (automatic method)...
# Done in 376ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 11ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 31ms.
# Solving linear system (automatic method)...
# Done in 299ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 9ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 28ms.
# Solving linear system (automatic method)...
# Done in 316ms.
# Optimizing (gradient descent)...
# Done in 9ms.
# Optimizing (multi-start)...
# Done in 7ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 15ms.
# Solving linear system (automatic method)...
# Done in 349ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 10ms.
# ([[0.203125, 0.5], 9.193123758467692, [0.20289427055856674, 0.20247841054329493], 0.28735183391265906], 521)
#
# ################################################## Current Budget: 573 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 29ms.
# Solving linear system (automatic method)...
# Done in 541ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 11ms.
# 573
# Adaptive grid generation (Ritter-Novak)...
# Done in 29ms.
# Solving linear system (automatic method)...
# Done in 576ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 11ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 27ms.
# Solving linear system (automatic method)...
# Done in 405ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 6ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 28ms.
# Solving linear system (automatic method)...
# Done in 415ms.
# Optimizing (gradient descent)...
# Done in 5ms.
# Optimizing (multi-start)...
# Done in 8ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 19ms.
# Solving linear system (automatic method)...
# Done in 201ms.
# Optimizing (gradient descent)...
# Done in 3ms.
# Optimizing (multi-start)...
# Done in 7ms.
# ([[0.1875, 0.1875], 5.8891143762690925, [0.2013543443956023, 0.20172017240880363], 0.09501544621541669], 573)
#
# ################################################## Current Budget: 625 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 25ms.
# Solving linear system (automatic method)...
# Done in 466ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 8ms.
# 625
# Adaptive grid generation (Ritter-Novak)...
# Done in 19ms.
# Solving linear system (automatic method)...
# Done in 451ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 11ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 29ms.
# Solving linear system (automatic method)...
# Done in 388ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 9ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 20ms.
# Solving linear system (automatic method)...
# Done in 987ms.
# Optimizing (gradient descent)...
# Done in 14ms.
# Optimizing (multi-start)...
# Done in 7ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 18ms.
# Solving linear system (automatic method)...
# Done in 233ms.
# Optimizing (gradient descent)...
# Done in 3ms.
# Optimizing (multi-start)...
# Done in 10ms.
# ([[0.1875, 0.1875], 5.889114376269034, [0.2025414840995321, 0.20311051242664674], 0.31921647333671643], 625)
#
# ################################################## Current Budget: 677 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 20ms.
# Solving linear system (automatic method)...
# Done in 471ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 7ms.
# 677
# Adaptive grid generation (Ritter-Novak)...
# Done in 24ms.
# Solving linear system (automatic method)...
# Done in 538ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 13ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 21ms.
# Solving linear system (automatic method)...
# Done in 502ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 8ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 23ms.
# Solving linear system (automatic method)...
# Done in 1133ms.
# Optimizing (gradient descent)...
# Done in 21ms.
# Optimizing (multi-start)...
# Done in 17ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 33ms.
# Solving linear system (automatic method)...
# Done in 318ms.
# Optimizing (gradient descent)...
# Done in 3ms.
# Optimizing (multi-start)...
# Done in 10ms.
# ([[0.1875, 0.1875], 5.88911437626902, [0.2031249994740956, 0.20136721263306256], 0.2301858537714665], 677)
#
# ################################################## Current Budget: 729 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 30ms.
# Solving linear system (automatic method)...
# Done in 482ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 9ms.
# 729
# Adaptive grid generation (Ritter-Novak)...
# Done in 23ms.
# Solving linear system (automatic method)...
# Done in 613ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 9ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 23ms.
# Solving linear system (automatic method)...
# Done in 549ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 16ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 50ms.
# Solving linear system (automatic method)...
# Done in 1426ms.
# Optimizing (gradient descent)...
# Done in 21ms.
# Optimizing (multi-start)...
# Done in 9ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 23ms.
# Solving linear system (automatic method)...
# Done in 340ms.
# Optimizing (gradient descent)...
# Done in 3ms.
# Optimizing (multi-start)...
# Done in 13ms.
# ([[0.1875, 0.1875], 5.889114376269047, [0.20195336578405632, 0.20204530344897356], 0.15848385036637325], 729)
#
# ################################################## Current Budget: 781 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 28ms.
# Solving linear system (automatic method)...
# Done in 588ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 15ms.
# 781
# Adaptive grid generation (Ritter-Novak)...
# Done in 50ms.
# Solving linear system (automatic method)...
# Done in 858ms.
# Optimizing (gradient descent)...
# Done in 2ms.
# Optimizing (multi-start)...
# Done in 16ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 33ms.
# Solving linear system (automatic method)...
# Done in 795ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 12ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 55ms.
# Solving linear system (automatic method)...
# Done in 1968ms.
# Optimizing (gradient descent)...
# Done in 15ms.
# Optimizing (multi-start)...
# Done in 12ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 28ms.
# Solving linear system (automatic method)...
# Done in 400ms.
# Optimizing (gradient descent)...
# Done in 5ms.
# Optimizing (multi-start)...
# Done in 9ms.
# ([[0.1875, 0.1875], 5.889114376269048, [0.2012010925285173, 0.20226393008621782], 0.13011998693636428], 781)
#
# ################################################## Current Budget: 833 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 32ms.
# Solving linear system (automatic method)...
# Done in 733ms.
# Optimizing (gradient descent)...
# Done in 0ms.
# Optimizing (multi-start)...
# Done in 11ms.
# 833
# Adaptive grid generation (Ritter-Novak)...
# Done in 35ms.
# Solving linear system (automatic method)...
# Done in 977ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 18ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 36ms.
# Solving linear system (automatic method)...
# Done in 852ms.
# Optimizing (gradient descent)...
# Done in 2ms.
# Optimizing (multi-start)...
# Done in 10ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 42ms.
# Solving linear system (automatic method)...
# Done in 1996ms.
# Optimizing (gradient descent)...
# Done in 18ms.
# Optimizing (multi-start)...
# Done in 10ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 32ms.
# Solving linear system (automatic method)...
# Done in 474ms.
# Optimizing (gradient descent)...
# Done in 5ms.
# Optimizing (multi-start)...
# Done in 8ms.
# ([[0.1875, 0.1875], 5.889114376269062, [0.20312499989722538, 0.203124999897226], 0.38624749161100524], 833)
#
# ################################################## Current Budget: 885 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 32ms.
# Solving linear system (automatic method)...
# Done in 920ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 10ms.
# 885
# Adaptive grid generation (Ritter-Novak)...
# Done in 38ms.
# Solving linear system (automatic method)...
# Done in 1010ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 16ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 36ms.
# Solving linear system (automatic method)...
# Done in 931ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 14ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 42ms.
# Solving linear system (automatic method)...
# Done in 2380ms.
# Optimizing (gradient descent)...
# Done in 29ms.
# Optimizing (multi-start)...
# Done in 12ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 37ms.
# Solving linear system (automatic method)...
# Done in 548ms.
# Optimizing (gradient descent)...
# Done in 4ms.
# Optimizing (multi-start)...
# Done in 9ms.
# ([[0.1875, 0.1875], 5.889114376269007, [0.20312499989722393, 0.2031249998972274], 0.3862474916110017], 885)
#
# ################################################## Current Budget: 937 ##################################################
#
# Performing sparse search
# Adaptive grid generation (Ritter-Novak)...
# Done in 42ms.
# Solving linear system (automatic method)...
# Done in 885ms.
# Optimizing (gradient descent)...
# Done in 1ms.
# Optimizing (multi-start)...
# Done in 10ms.
# 937
# Adaptive grid generation (Ritter-Novak)...
# Done in 43ms.
# Solving linear system (automatic method)...
# Done in 1040ms.
# Optimizing (gradient descent)...
# Done in 2ms.
# Optimizing (multi-start)...
# Done in 13ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 42ms.
# Solving linear system (automatic method)...
# Done in 965ms.
# Optimizing (gradient descent)...
# Done in 2ms.
# Optimizing (multi-start)...
# Done in 14ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 44ms.
# Solving linear system (automatic method)...
# Done in 2097ms.
# Optimizing (gradient descent)...
# Done in 12ms.
# Optimizing (multi-start)...
# Done in 11ms.
# Adaptive grid generation (Ritter-Novak)...
# Done in 28ms.
# Solving linear system (automatic method)...
# Done in 518ms.
# Optimizing (gradient descent)...
# Done in 4ms.
# Optimizing (multi-start)...
# Done in 9ms.
# ([[0.1875, 0.1875], 5.889114376269115, [0.20266781037267267, 0.20145880328819887], 0.1830617759601978], 937)
# {(1,18.0)(53,17.954603830243304)(105,17.954601241487484)(157,17.954601241487484)(209,17.95460124148829)(261,17.954601241487573)(313,17.95460124148752)(365,17.954601241487435)(417,17.95460124148751)(469,17.954601241487524)(521,17.954601241487467)(573,17.954601241487463)(625,17.954601241487506)(677,17.954601241487463)(729,17.95460124148793)(781,17.954601241488138)(833,17.954601241487886)(885,17.954601241487513)(937,17.954601241488046)}
# {(1,18.0)(53,9.995024358227056)(105,9.994959057644616)(157,9.994959057644616)(209,9.994959057646103)(261,9.99495905764463)(313,9.994959057644524)(365,9.99495905764453)(417,9.99495905764462)(469,9.994959057644579)(521,9.994959057644468)(573,9.994959057644502)(625,9.994959057644628)(677,9.994959057644607)(729,9.99495905764461)(781,9.994959057644595)(833,9.99495905764462)(885,9.994959057644616)(937,9.994959057644667)}
# {(1,18.0)(53,9.995024358227056)(105,9.994959057644618)(157,9.000000184767032)(209,9.000000000721773)(261,9.0000000007217)(313,9.000000000721338)(365,9.000000000721721)(417,9.00000000072155)(469,9.00000000072114)(521,9.000000000721972)(573,9.000000000721784)(625,9.00000000072177)(677,9.000000000721762)(729,9.00000000072182)(781,9.000000000721915)(833,9.000000000721828)(885,9.000000000721684)(937,9.000000000721721)}
# {(1,18.0)(53,9.995597577515051)(105,9.994959320973711)(157,9.193123758467696)(209,9.000000000721291)(261,9.000000000720725)(313,9.00000000073414)(365,9.000000000715445)(417,9.000000000715788)(469,9.00000000072136)(521,5.889114376269022)(573,0.001513592628570368)(625,1.9994962252604298e-07)(677,1.2455895805700494e-08)(729,1.2778394708011167e-08)(781,1.2291804361994243e-08)(833,1.179890717001382e-08)(885,1.251678228282502e-08)(937,1.231146666513552e-08)}
# {(1,18.0)(53,11.944557188134524)(105,11.944557188134521)(157,10.130623758467696)(209,10.130623758467692)(261,9.193123758467797)(313,9.193123758467703)(365,9.193123758467696)(417,9.1931237584677)(469,9.1931237584677)(521,9.193123758467692)(573,5.8891143762690925)(625,5.889114376269034)(677,5.88911437626902)(729,5.889114376269047)(781,5.889114376269048)(833,5.889114376269062)(885,5.889114376269007)(937,5.889114376269115)}

# %%
f = ExampleFunction()
f.eval([0.25,0.25])
# Out:
# 40.5
